# %%
import mysql.connector
from bs4 import BeautifulSoup
import requests
import pandas as pd

# Make HTTP get request
url = "https://en.wikipedia.org/wiki/List_of_NFL_franchise_owners"
page = requests.get(url)
page.status_code

# Parse content
content = BeautifulSoup(page.text, "html.parser")
#content.text

# Get data table
table = content.find("table", class_="wikitable sortable")
# Save in Pandas dataframe?
df = pd.read_html(str(table))
df = pd.DataFrame(df[0])
df.describe()
df
# Out:
#                    Franchise  \
# 0          Arizona Cardinals
# 1            Atlanta Falcons
# 2           Baltimore Ravens
# 3              Buffalo Bills
# 4          Carolina Panthers
# 5              Chicago Bears
# 6         Cincinnati Bengals
# 7           Cleveland Browns
# 8             Dallas Cowboys
# 9             Denver Broncos
# 10             Detroit Lions
# 11         Green Bay Packers
# 12            Houston Texans
# 13        Indianapolis Colts
# 14      Jacksonville Jaguars
# 15        Kansas City Chiefs
# 16         Las Vegas Raiders
# 17      Los Angeles Chargers
# 18          Los Angeles Rams
# 19            Miami Dolphins
# 20         Minnesota Vikings
# 21      New England Patriots
# 22        New Orleans Saints
# 23           New York Giants
# 24             New York Jets
# 25       Philadelphia Eagles
# 26       Pittsburgh Steelers
# 27       San Francisco 49ers
# 28          Seattle Seahawks
# 29      Tampa Bay Buccaneers
# 30          Tennessee Titans
# 31  Washington Football Team
#
#                                    Principal Owner(s)     Purchase Price  \
# 0                            Estate of Bill Bidwill‡6            $50,000
# 1                                      Arthur Blank†1       $545,000,000
# 2                                   Steve Bisciotti†1      $300M & $600M
# 3                                Kim and Terry Pegula     $1,400,000,000
# 4                                        David Tepper     $2,275,000,000
# 5                          Virginia Halas McCaskey†‡2               $100
# 6                                        Mike Brown‡2          >$200M[7]
# 7                                Jimmy and Dee Haslam  $1,050,000,000[9]
# 8                                         Jerry Jones       $140,000,000
# 9                                 Joe Ellis, trustee6        $71,000,000
# 10                             Sheila Ford Hamp†‡[13]         $4,500,000
# 11                           Green Bay Packers, Inc.4                  -
# 12                        Janice McNair and family†‡2       $700,000,000
# 13                                         Jim Irsay‡        $19,000,000
# 14                                        Shahid Khan       $760,000,000
# 15                          Clark Hunt and siblings‡2            $25,000
# 16            Carol and Mark Davis (mother and son)†‡                  -
# 17                                       Dean Spanos‡       >$72,000,000
# 18                                      Stan Kroenke1       $80M & $450M
# 19                                   Stephen M. Ross†     $1,000,000,000
# 20                                         Zygi Wilf†       $600,000,000
# 21                                       Robert Kraft       $175,000,000
# 22                                      Gayle Benson‡        $64,000,000
# 23                John Mara‡ (50%)3 Steve Tisch (50%)               $500
# 24  Robert Wood Johnson IV5 and Christopher Wold J...       $635,000,000
# 25                                      Jeffrey Lurie       $185,000,000
# 26     Art Rooney II‡1,3 (60%) and family (12%)‡1,2,3             $2,500
# 27               Denise DeBartolo York and Jed York‡1        $17,000,000
# 28                              Jody Allen, trustee‡6       $200,000,000
# 29                         Bryan Glazer and siblings‡       $192,000,000
# 30                                Amy Adams Strunk‡ 2            $25,000
# 31                                        Dan Snyder†       $800,000,000
#
#         Yearacquired
# 0            1932[1]
# 1            2002[2]
# 2     2000 & 2004[3]
# 3            2014[4]
# 4            2018[5]
# 5            1920[6]
# 6     1968[8] & 2011
# 7           2012[10]
# 8           1989[11]
# 9           1984[12]
# 10      1963[14][15]
# 11              1923
# 12          1999[16]
# 13          1972[17]
# 14          2012[18]
# 15          1960[19]
# 16              2011
# 17  1984[20][21][22]
# 18   1995 & 2010[23]
# 19          2008[24]
# 20          2005[25]
# 21          1994[26]
# 22          1985[27]
# 23          1925[28]
# 24          2000[29]
# 25          1994[30]
# 26          1933[31]
# 27          1977[32]
# 28          1997[33]
# 29          1995[34]
# 30      1959[35][36]
# 31          1999[37]
